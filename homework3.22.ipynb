# %%
# %matplotlib inline

import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
df= pd.read_csv('https://quality.data.gov.tw/dq_download_csv.php?nid=35960&md5_url=a99f0ed3ab1ebca94bd53b0938f4ebec')

# %%
df.head()
# Out:
#    Field1  Field2  Field3  Field4  Field5  Field6  Field7  Field8  Field9  \
# 0  2006.0     3.9     3.6     2.9     2.7     3.7     2.7     3.7     3.8
# 1  2007.0     3.8     3.8     7.1     3.7     3.7     3.3     3.6     4.6
# 2  2008.0     4.2     3.8     6.7     6.4     4.5     4.0     3.6     4.6
# 3  2009.0     6.5     5.1    13.2     4.7     6.9     5.3     5.5     4.7
# 4  2010.0     5.9     4.4     3.9     2.0     6.4     4.3     6.2     4.9
#
#    Field10  Field11  Field12  Field13  Field14  Field15 Field16 Field17
# 0      4.4      4.1      3.6      3.4      4.7      4.1     ...     ...
# 1      4.1      4.8      3.5      2.8      4.2      4.2     ...     ...
# 2      4.8      3.7      4.0      2.6      4.4      4.9     ...     ...
# 3      7.6      5.1      6.0      4.5      5.8      6.1     ...     ...
# 4      6.7      4.6      5.5      4.0      5.5      5.1     ...     ...

# %%
v=[3.9, 3.6, 2.9, 2.7, 3.7, 2.7, 3.8, 4.4, 4.1, 3.6, 3.4, 4.7, 4.1]
w=[3.8, 3.8, 7.1, 3.7, 3.7, 3.3 , 3.6, 4.6, 4.1, 4.8, 3.5, 2.8, 4.2, 4.2]
x=[4.2, 3.8, 6.7, 6.4, 4.5, 4.0, 3.6, 4.6, 4.8, 3.7, 4.0, 2.6, 4.4, 4.9]
y=[6.5, 5.1, 13.2, 4.7, 6.9, 5.3, 5.5, 4.7, 7.6, 5.1, 6.0, 4.5, 5.8, 6.1]
z=[5.9, 4.4, 3.9, 2.0, 6.4, 4.3, 6.2, 4.9, 6.7, 4.6, 5.5, 4.0, 5.5, 5.1]
plt.plot(v, color='red', label='2006')
plt.plot(w, color='blue', label='2007')
plt.plot(x, color='green', label='2008')
plt.plot(y, color='yellow', label='2009')
plt.plot(z, color='black', label='2010')
plt.xlabel('month')
plt.ylabel('rate')
plt.legend()

plt.show()
